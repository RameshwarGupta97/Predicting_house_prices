# %% [markdown]
# <img src="https://drexel.edu/~/media/Images/now/ui/og-drexel-logo.ashx" alt="Smiley face" width="60" height="60" style="float:left">
#
# ### College of Computing and Informatics, Drexel University</br>
# ### INFOT780: Applied Machine Learning, Summer 2020
# ### Due: Wednesday, Sept. 2, 2020
# ---
# <a name="top"></a>
# ## Final Project Report
#
# ## Project Title: House Prices: Advanced Regression Techniques
#
# ## Team: Group 1
#
# ## Student(s):
#
# 1. Rameshwar Gupta - rg859@drexel.edu
# 2. Syed Talmeez Ahmed - ts3377@drexel.edu
# 3. Lakshmi Kanth Peddinti - lk596@drexel.edu
# 4. Sumit Anand - sa3665@drexel.edu
#
#
# #### Date:09/02/2020
# ---

# %% [markdown]
# <a id="31"></a>
#
# # <font color = 'brown'> Table of Contents</font>
#
#
#
# * [Abstract](#1)
#     * [1.1 Frame the problem and look at the big picture](#1)
#     * [1.2 Introduction](#1.2)
#     * [1.3 Import necessary libraries](#1.3)
#
#
# * [2. Get the data](#2)
# * [3. Explore the data to gain insights](#3)
#
# * [4. Prepare the data to better expose the underlying data patterns to Machine Learning algorithms](#4)
#     * [4.1 Dropping  few variables](#4.1)
#     * [4.2 Filling Missing values with 0](#4.2)
#     * [4.3 Check for skewness in features and transform them](#4.3)
#     * [4.4 Transform skewed features](#4.4)
#     * [4.5 Convert categorical to continuous using get_dummies](#4.5)
#     * [4.6 Create new train and test(submission) datasets](#4.6)
#     * [4.7 Create new train and test(internal testing) datasets](#4.7)
#     * [4.8 Plotting PCA with n_components = 0.9](#4.8)
#
#
# * [5. Explore many different models and shortlist the best ones](#5)
#     * [5.1 Creating a function to test the model accuracy and update the data in a table](#5.1)
#     * [5.2 Running different regression models with default hyper parameters to test the accuracy](#5.2)
#         * [5.2.1 Linear Regression](#5.2.1)
#         * [5.2.2 Random Forest Regressor](#5.2.2)
#         * [5.2.3 Decision Tree Regressor](#5.2.3)
#         * [5.2.4 LGBM Regressor](#5.2.4)
#         * [5.2.5 Ridge Regression](#5.2.5)
#         * [5.2.6 KNeighbors Regressor](#5.2.6)
#         * [5.2.7 Epsilon-Support Vector Regressor](#5.2.7)
#         * [5.2.8 ExtraTrees Regressor](#5.2.8)
#         * [5.2.9 Gradient Boosting Regressor](#5.2.9)
#         * [5.2.10 XGB Regressor](#5.2.10)
#
#     * [5.3 Running different regression models with ```cross_val_score``` to test the accuracy](#5.3)
#     * [5.4 Testing on Neural Networks](#5.4)
#     * [5.5 Testing with Keras Regression - Using a Scalar](#5.5)
#
#
# * [6. Fine-tune your models and combine them into a great solution.](#6)
#     * [6.1 Creating RandomizedSearchCV pipeline to tune parameters for different models](#6.1)
#     * [6.2 Running RandomizedSearchCV function on version 1 dataset](#6.2)
#     * [6.3 Running RandomizedSearchCV function on version 2 dataset](#6.3)
#
#
# * [7. Present your solution](#7)
#     * [7.1 Base Model Scores](#7.1)
#     * [7.2 Base Model Scores with cross validation](#7.2)
#     * [7.3 Grid Search Results](#7.3)
#     * [7.4 Plotting train and test data using Yellowbrick visualiser](#7.4)
#     * [7.5 Predictions](#7.5)
#
# * [8. Conclusion](#8)
# * [9. References](#9)

# %% [markdown]
# <!-- ![](https://drexel.edu/~/media/Images/now/ui/og-drexel-logo.ashx) -->

# %% [markdown]
# <a id="1"></a>
# ## <font color ='brown'><b>1. Abstract</font>
# ---
# *(Briefly summarize the project including the problem, data sets, modeling process, and final results.)*

# %% [markdown]
# ### <font color ='green'><b> 1.1 Frame the problem and look at the big picture: </b></font>
#
# + This project is to predict the Sale Price of residential homes in Ames, Iowa.  By taking into consideration of over 79 features of a residential home, we will build a model which can predict the price of that house.
#
# + This competition's dataset proves that much more influences price negotiations than the number of bedrooms or a white-picket fence.
#
#
# <font color ='brown'><b>About Dataset: </b></font>
#
# + We obtained our dataset from the kaggle competetions and the source is : https://www.kaggle.com/c/house-prices-advanced-regression-techniques/overview.
# + This dataset contains Train and Test datasets.</br>
# + The training dataset has 81 columns with 1460 instances.</br>
# + The test dataset has 80 columns with 1460 instances.</br>
# + We need to predict the sales price in the dataset.</br>
# + We will be using complete data from the project. It has large number of dimensions with 80 independent variables. </br>
#
#
# <font color ='brown'><b>Modeling Process: </b></font>
#
# + For pre-processing we will use dimensionality reduction techniques to use these predictors in our solution.
# + We will use different models with default parameters and later use Randomcvsearch to fine tune the hyper parameters to find the best model.
#
#
# <font color ='brown'><b>Final Results: </b></font>
#
# + Our dependent variable is SalePrice variable which we will train the model to predict.
# + Final results would be predicting the values in the test dataset and updating the sample submission file as required in the kaggle competetion.
#
# </p>
#
# <a href="#top">Back to top of page</a>

# %% [markdown]
# <a id="1.2"></a>
#
# ### <font color ='green'><b> 1.2 Introduction</font>
# ---
# *(Introduce the competition problem, describe your modeling process, and present the results. This section will provide an overview of the entire project including the description of the data sets, and the specific data analysis, wrangling, modeling, and evaluation techniques.)*

# %% [markdown]
# <font color ='brown'><b>Competetion Problem: </b></font>
#
# + This competetion's problem is to predict ```SalePrice``` variable using different features present about the houses in Ames, Iowa.
# + Final results would be predicting the values in the test dataset and updating the sample submission file as required in the kaggle competetion.
#
#
# <font color ='brown'><b>Wrangling: </b></font>
#
# + We have used different imputing techniques to updating missing values.
#     + We updated some feature values with '0'.
#     + We updated some features with 'Most frequent values'.</br>
# </br>
#
# + Target variable was right skewed so we used log transformation to convert the feature to normal distribution.
# + We utilised Box Cox transformation which is a way to transform non-normal dependent variables into a normal shape to transform the features which are skewed.
#
#
# <font color ='brown'><b>Modelling: </b></font>
#
# + We have first tested the default models.
# + Then used RandomCVsearch to tune the hyper-parameters of the models.
#
#
# 1. Linear Regression
# 2. Random Forest Regressor
# 3. Decision Tree Regressor
# 4. LGBM Regressor
# 5. Ridge Regression
# 6. KNeighbors Regressor
# 7. Epsilon-Support Vector Regressor
# 8. ExtraTrees Regressor
# 9. Gradient Boosting Regressor
# 10. XGB Regressor
#
#
# + Running different regression models with cross_val_score to test the accuracy
#
# <font color ='brown'><b>Evaluation Techniques: </b></font>
#
# + We have used r2 as our main accuracy testing metric to finalise the model.
# + We have used Cross_Val_score to check different train-test split combinations to find the best score.
# + We have used Randomcvsearch to fine tune the hyper parameters of the different models we have tested with default parameters.
# + We have tabulated all the details to compare them.
#
# <a href="#7">Click here to view the results</a>
#
#
# <a href="#top">Back to top of page</a>

# %% [markdown]
# #### <font color ='brown'><b>Data Description: We have added the ```data_description.txt``` file which has all the details about the features present in this project</b></font>

# %% [markdown]
# <a id="1.3"></a>
#
# ### <font color ='green'><b>1.3 Import necessary libraries

# %%
# Importing Basic Libraries
print('Importing Basic Libraries')
import pandas as pd
import numpy as np
import warnings

# Importing Plotting libarries
print('Importing Plotting libarries')
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
import seaborn as sns
from yellowbrick.regressor import ResidualsPlot
from yellowbrick.regressor import prediction_error
from yellowbrick.regressor import PredictionError

# Importing sklearn libraries - Pipelines
print('Importing sklearn libraries - Pipelines')
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import SimpleImputer, IterativeImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import SimpleImputer, IterativeImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# Importing sklearn libraries required for Scaling
print('Importing sklearn libraries required for Scaling')
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import Normalizer



# Importing sklearn libraries required for Pre-Processing
print('Importing sklearn libraries required for Pre-Processing')
from scipy.stats import skew, norm, boxcox_normmax
from scipy.special import boxcox1p

# Importing sklearn libraries required for checking accuracy
print('Importing sklearn libraries required for checking accuracy')
from sklearn.metrics import mean_squared_error, mean_absolute_error,mean_squared_log_error, r2_score
from sklearn.model_selection import KFold, StratifiedKFold, RandomizedSearchCV, train_test_split


# Importing sklearn Models
print('Importing sklearn Models')
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, GradientBoostingRegressor, StackingRegressor
from sklearn.svm import SVR
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from xgboost import XGBRegressor, plot_importance as plot_importance_xgb
from lightgbm import LGBMRegressor, plot_importance as plot_importance_lgbm
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import SimpleImputer, IterativeImputer
from sklearn.neighbors import KNeighborsRegressor
from scipy import stats

# Importing and setting necessary formats
print('Importing and setting necessary formats')
pd.set_option('display.max_columns', 500) # Setting pandas to display a N number of columns
pd.set_option('display.max_rows', 30) # Setting pandas to display a N number rows
pd.set_option('display.width', 1000) # Setting pandas dataframe display width to N

warnings.filterwarnings('ignore')
plt.style.use('ggplot')
# %matplotlib inline
print('Notebook is ready')
# Out:
# Importing Basic Libraries
# Importing Plotting libarries
# Importing sklearn libraries - Pipelines
# Importing sklearn libraries required for Scaling
# Importing sklearn libraries required for Pre-Processing
# Importing sklearn libraries required for checking accuracy
# Importing sklearn Models
# Importing and setting necessary formats
# Notebook is ready

# %% [markdown]
# <a href="#top">Back to top of page</a>

# %% [markdown]
# <a id="2"></a>
# ## <font color ='brown'><b> 2. Get the data : </b></font>

# %% [markdown]
# #### <font color ='brown'><b> Note: Code below for both kaggle and local notebooks.</b></font>

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# For Kaggle
# train = pd.read_csv('../input/house-prices-advanced-regression-techniques/train.csv')
# test = pd.read_csv('../input/house-prices-advanced-regression-techniques/test.csv')


print('Imported data to train and test dataframes')
print("Train and Test data shape",train.shape,test.shape)
# Out:
# Imported data to train and test dataframes
# Train and Test data shape (1460, 81) (1459, 80)

# %%
display(train.head())
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape LandContour Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold SaleType SaleCondition  SalePrice
# ...

# %%
print("Dropping the ID field in both Train and Test data sets")
train.drop("Id", axis = 1, inplace = True)
test.drop("Id", axis = 1, inplace = True)
# Out:
# Dropping the ID field in both Train and Test data sets

# %% [markdown]
# <a href="#top">Back to top of page</a>

# %% [markdown]
# <a id="3"></a>
# ## <font color ='brown'><b> 3. Explore the data to gain insights : </b></font>

# %% [markdown]
# ---
# *(Study each attribute and its characteristics. Study the correlations between attributes. Study how you would solve the problem manually. Identify the promising transformations you may want to apply.)*

# %%
print('Train Shape is:',train.shape,'\nTest Shape is:',test.shape)
# Out:
# Train Shape is: (1460, 80)
# Test Shape is: (1459, 79)

# %%
fig, ax = plt.subplots()
ax.scatter(x = train['GrLivArea'], y = train['SalePrice'])
plt.title("Check for outliers between SalePrice and GrLivArea(Above grade (ground) living area square feet)")
plt.ylabel('SalePrice', fontsize=13)
plt.xlabel('GrLivArea', fontsize=13)
plt.show()

# %%
#Deleting outliers
print("There are extremely large GrLivArea values to the right that are of a low price. These values are huge oultliers. Therefore, we can safely delete them.")
train = train.drop(train[(train['GrLivArea']>4000) & (train['SalePrice']<300000)].index)

#Check the graphic again
fig, ax = plt.subplots()
ax.scatter(train['GrLivArea'], train['SalePrice'])
plt.ylabel('SalePrice', fontsize=13)
plt.xlabel('GrLivArea', fontsize=13)
plt.show()
# Out:
# There are extremely large GrLivArea values to the right that are of a low price. These values are huge oultliers. Therefore, we can safely delete them.

# %% [markdown]
# We will be handling rest of the ooutliers in the modelling stage of the project.

# %%
from scipy import stats
from scipy.stats import norm, skew #for some statistics
def check_norm():
    sns.distplot(train['SalePrice'] , fit=norm);

    # Get the fitted parameters used by the function
    (mu, sigma) = norm.fit(train['SalePrice'])
    print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))

    #Now plot the distribution
    plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)],loc='best')
    plt.ylabel('Frequency')
    plt.title('SalePrice distribution')

    #Get also the QQ-plot
    fig = plt.figure()
    res = stats.probplot(train['SalePrice'], plot=plt)
    plt.show()
check_norm()
# Out:
#  mu = 180932.92 and sigma = 79467.79

# %% [markdown]
# ### We have a right skewed target variable. We can transform the variable to be more of normal distribution.

# %%
#We use the numpy fuction log1p which  applies log(1+x) to all elements of the column
train["SalePrice"] = np.log1p(train["SalePrice"])
check_norm()
print("The skew seems now corrected and the data appears more normally distributed.")
# Out:
#  mu = 12.02 and sigma = 0.40
# The skew seems now corrected and the data appears more normally distributed.

# %%
train_shape = train.shape[0]
test_shape = test.shape[0]
y_train = train.SalePrice.values
full_data = pd.concat((train, test)).reset_index(drop=True)
# full_data.drop(['SalePrice'], axis=1, inplace=True)
print("Full_data size is with train and test data is : {}".format(full_data.shape))
# Out:
# Full_data size is with train and test data is : (2917, 80)

# %%
print('All variables with NaN values - Sorted\n')
(full_data.isna().sum()[full_data.isna().sum()>0]).sort_values(ascending=False)
# Out:
# All variables with NaN values - Sorted
# PoolQC         2908
# MiscFeature    2812
# Alley          2719
# Fence          2346
# SalePrice      1459
#                ...
# Exterior2nd       1
# Exterior1st       1
# GarageCars        1
# GarageArea        1
# Electrical        1
# Length: 35, dtype: int64

# %% [markdown]
# <font color ='brown'><b>Function to check the categorical and continuous values</b></font>

# %%
def check_length(df):
    # Get list of categorical variables
    s = (df.dtypes == 'object')
    object_cols = list(s[s].index)

    # Get list of continuous variables
    c = (df.dtypes != 'object')
    continuous_cols = list(c[c].index)

    print("Categorical variables length:",len(object_cols))
#     print(object_cols)
    print()
    print("Continuous variables length:",len(continuous_cols))
#     print(continuous_cols)
    return object_cols,continuous_cols
object_cols,continuous_cols = check_length(full_data)
# Out:
# Categorical variables length: 43
#
# Continuous variables length: 37

# %%
print('Categorical variables with NaN values\n')
display((full_data[object_cols].isna().sum()[full_data[object_cols].isna().sum()>0]).sort_values(ascending=False))
# Out:
# Categorical variables with NaN values
# PoolQC          2908
# MiscFeature     2812
# Alley           2719
# Fence           2346
# FireplaceQu     1420
# GarageCond       159
# GarageQual       159
# GarageFinish     159
# GarageType       157
# BsmtExposure      82
# BsmtCond          82
# BsmtQual          81
# BsmtFinType2      80
# BsmtFinType1      79
# MasVnrType        24
# MSZoning           4
# Functional         2
# Utilities          2
# Exterior1st        1
# SaleType           1
# Exterior2nd        1
# KitchenQual        1
# Electrical         1
# dtype: int64

# %%
print('Continuous variables with NaN values\n')
display((full_data[continuous_cols].isna().sum()[full_data[continuous_cols].isna().sum()>0]).sort_values(ascending=False))
# Out:
# Continuous variables with NaN values
# SalePrice       1459
# LotFrontage      486
# GarageYrBlt      159
# MasVnrArea        23
# BsmtHalfBath       2
# BsmtFullBath       2
# GarageArea         1
# GarageCars         1
# TotalBsmtSF        1
# BsmtUnfSF          1
# BsmtFinSF2         1
# BsmtFinSF1         1
# dtype: int64

# %%
plt.figure(figsize=(10,6))
plt.title("NA values of 'GarageYrBlt','GarageType','GarageFinish','GarageQual','GarageCond'")
sns.heatmap(full_data[['GarageYrBlt','GarageType','GarageFinish','GarageQual','GarageCond']].isnull(),yticklabels=False,cmap='viridis')
print()

# %%
plt.figure(figsize=(10,5))
plt.title("NA values of 'BsmtFinType2','BsmtExposure','BsmtFinType1','BsmtCond','BsmtQual'")

sns.heatmap(full_data[['BsmtFinType2','BsmtExposure','BsmtFinType1','BsmtCond','BsmtQual']].isnull(),yticklabels=False,cmap='viridis')
print()

# %% [markdown]
# <font color ='brown'><b>Observation on NA values: </b></font>
# + Missing values need to be handled individually because most of the NA values don't mean that they are missing. This was described in the data dictionary that NA mean something meaningful. For example NA values in FirePlaceQu means there is no Fire Place. So we are going to update those 'NA' values to 'None'.
# + We have updated a comment next to every imputation on the reason from the data dictionary below.

# %% [markdown]
# <font color ='green'><b>Distributions of Continuous Features</b></font>

# %%
df_num = full_data.select_dtypes(include = ['float64', 'int64'])
df_num.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8);

# %% [markdown]
# Features such as `1stFlrSF`, `TotalBsmtSF`, `LotFrontage`, `GrLiveArea` share a similar distribution to the one we have with `SalePrice`.

# %%
df_num_corr = df_num.corr()['SalePrice'][:-1] # -1 because the latest row is SalePrice
important_features_list = df_num_corr[abs(df_num_corr) > 0.5].sort_values(ascending=False)
print("There is {} strongly correlated values with SalePrice:\n{}".format(len(important_features_list), important_features_list))
# Out:
# There is 11 strongly correlated values with SalePrice:
# OverallQual     0.821405
# GrLivArea       0.725211
# GarageCars      0.681033
# GarageArea      0.656129
# TotalBsmtSF     0.647563
# 1stFlrSF        0.620500
# FullBath        0.595899
# YearBuilt       0.587043
# YearRemodAdd    0.565992
# GarageYrBlt     0.541638
# TotRmsAbvGrd    0.537702
# Name: SalePrice, dtype: float64

# %% [markdown]
# By looking at correlation between numerical values we discovered 11 features which have a strong relationship to a house price. Besides correlation we didn't find any notable pattern on the data which are not correlated.

# %% [markdown]
# -----------

# %% [markdown]
# <font color ='green'><b>Plotting Correlation for all the features </b></font>

# %%
corr = full_data.corr()
plt.subplots(figsize=(15,12))
sns.heatmap(corr, vmax=0.9, square=True)

# %% [markdown]
# <font color ='green'>Because of the high dimensions its really hard to interpret anything from the above plot</font>

# %% [markdown]
# <font color ='green'><b>Ploting Correlation for numeric features </b></font>

# %%
corr_num = df_num.corr()
plt.subplots(figsize=(15,12))
sns.heatmap(corr_num, vmax=0.9, square=True)

# %% [markdown]
# + <font color ='green'>From above plot we are able to find some insights on which feature is most correlated. GarageCars and GarageArea is on positive side, which is understood as people with more garage area and more cars sale price would increase.
# + <font color ='green'>With SalePrice we can see OverallQual, GrLivArea, GarageCars, GarageArea, TotalBsmtSF, 1stFlrSF, FullBath, YearBuilt, YearRemodAdd, GarageYrBlt, TotRmsAbvGrd have good correlation with SalePrice.

# %% [markdown]
# <font color ='green'><b>Ploting Correlation for numeric features without SalePrice >0.5 and <-0.4</b></font>

# %%
corr = df_num.drop('SalePrice', axis=1).corr() # We already examined SalePrice correlations
plt.figure(figsize=(12, 10))

sns.heatmap(corr[(corr >= 0.5) | (corr <= -0.4)], 
            cmap='viridis', vmax=1.0, vmin=-1.0, linewidths=0.1,
            annot=True, annot_kws={"size": 8}, square=True);

# %% [markdown]
# + A lot of features seems to be correlated between each other but some of them such as YearBuild/GarageYrBlt may just indicate a price inflation over the years. As for 1stFlrSF/TotalBsmtSF, it is expected that larger the 1st floor area (considering many houses have only 1 floor), larger the total basement area will be.
#
# + Now for the ones which are less obvious we can see that:
#
# + There is a strong negative correlation between BsmtUnfSF (Unfinished square feet of basement area) and BsmtFinSF2 (Type 2 finished square feet).
# + HalfBath/2ndFlrSF is interesting and may indicate that people give importance of not having to rush downstairs to the bathroom.
# + There is of course a lot more to discover but we can't really explain the rest of the features from this except the most obvious ones.

# %% [markdown]
# <font color ='green'><b>Relationship between major features</b></font>

# %%
for i in range(0, len(df_num.columns), 5):
    sns.pairplot(data=df_num,
                x_vars=df_num.columns[i:i+5],
                y_vars=['SalePrice'])

# %% [markdown]
# Observation:
#
# Above plot shows the relationships between the data. Many of them have linear relationship with the SalePrice. Also we can see many data points are located on x = 0 which may indicate the absence of such feature in the house.
#
# By looking at correlation between numerical values we discovered 11 features which have a strong relationship to a house price. Besides correlation we didn't find any notable pattern on the datas which are not correlated.

# %%
quantitative_features_list = ['LotFrontage', 'LotArea', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'TotalBsmtSF', '1stFlrSF',
    '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
    'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 
    'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'SalePrice']
df_quantitative_values = full_data[quantitative_features_list]
df_quantitative_values.head()
features_to_analyse = [x for x in quantitative_features_list if x in important_features_list]
features_to_analyse.append('SalePrice')
features_to_analyse


fig, ax = plt.subplots(round(len(features_to_analyse) / 3), 3, figsize = (18, 12))

for i, ax in enumerate(fig.axes):
    if i < len(features_to_analyse) - 1:
        sns.regplot(x=features_to_analyse[i],y='SalePrice', data=full_data[features_to_analyse], ax=ax)

# %% [markdown]
# We can see that features such as TotalBsmtSF, 1stFlrSF, GrLivArea have a big spread.

# %% [markdown]
# ### Categorical to Quantitative relationship

# %%
categorical_features = [a for a in quantitative_features_list[:-1] + full_data.columns.tolist() if (a not in quantitative_features_list[:-1]) or (a not in full_data.columns.tolist())]
df_categ = full_data[categorical_features]
# df_categ.head()


# Non-numerical features
df_not_num = df_categ.select_dtypes(include = ['O'])
print('There is {} non numerical features including:\n{}'.format(len(df_not_num.columns), df_not_num.columns.tolist()))
# Out:
# There is 43 non numerical features including:
# ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']

# %%
plt.figure(figsize = (10, 6))
ax = sns.boxplot(x='BsmtExposure', y='SalePrice', data=df_categ)
plt.setp(ax.artists, alpha=.5, linewidth=2, edgecolor="k")
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3]), <a list of 4 Text xticklabel objects>)

# %%
plt.figure(figsize = (12, 6))
ax = sns.boxplot(x='SaleCondition', y='SalePrice', data=df_categ)
plt.setp(ax.artists, alpha=.5, linewidth=2, edgecolor="k")
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4, 5]), <a list of 6 Text xticklabel objects>)

# %%
fig, axes = plt.subplots(round(len(df_not_num.columns) / 3), 3, figsize=(12, 30))

for i, ax in enumerate(fig.axes):
    if i < len(df_not_num.columns):
        ax.set_xticklabels(ax.xaxis.get_majorticklabels(), rotation=90)
        sns.countplot(x=df_not_num.columns[i], alpha=0.7, data=df_not_num, ax=ax)

fig.tight_layout()

# %% [markdown]
# Some of the above categories are predominant for some features such as `Utilities`, `Heating`, `GarageCond`, `Functional` etc.
# These features may not be relevant for our predictive model.
#
#
# <a href="#top">Back to top of page</a>

# %% [markdown]
# <a id="4"></a>
# ## <font color ='brown'><b> 4. Prepare the data to better expose the underlying data patterns to Machine Learning algorithms: </b></font>

# %% [markdown]
# ---
# *(Clean and wrangle the data including fixing or removing outliers, dealing with missing values, feature scaling, feature transformation, and more. Write necessary functions for reuse and modularization.)*

# %% [markdown]
# <a id="4.1"></a>
# ### <font color ='green'><b> 4.1 Dropping  few variables</b></font>

# %%
display((full_data.isna().sum()[full_data.isna().sum()>0]).sort_values(ascending=False))
# Out:
# PoolQC         2908
# MiscFeature    2812
# Alley          2719
# Fence          2346
# SalePrice      1459
#                ...
# Exterior2nd       1
# Exterior1st       1
# GarageCars        1
# GarageArea        1
# Electrical        1
# Length: 35, dtype: int64

# %%
print('As PoolQC, MiscFeature, Alley, Fence features have more than 80% missing data we will drop them')
full_data = full_data.drop(columns=['PoolQC','MiscFeature','Alley','Fence'])
# Out:
# As PoolQC, MiscFeature, Alley, Fence features have more than 80% missing data we will drop them

# %% [markdown]
# FireplaceQu, GarageX, BsmtX, MasVnrType impute them with None. If you look at the dataset, FirePlaceQu is NaN because there is not Fireplace in that house. Same logic for GarageX and BsmtX. MasVnrType is NaN bcoz there is no MasVnrArea. MSZoning and others impute with mode bcoz only <4 entries are missing for those attributes.

# %%
print('Out of ',full_data.shape[0],'rows we have ',len(full_data[full_data['YearBuilt']==full_data['GarageYrBlt']]),'rows where YearBuilt and GarageYrBlt are same. So better to drop one of these columns. We can drop the column with less correlation. Similarly dropping LotFrontage.')
full_data = full_data.drop(columns=['LotFrontage', 'GarageYrBlt'], axis=1)
# Out:
# Out of  2917 rows we have  2214 rows where YearBuilt and GarageYrBlt are same. So better to drop one of these columns. We can drop the column with less correlation. Similarly dropping LotFrontage.

# %% [markdown]
# <a id="4.2"></a>
# ### <font color ='green'><b> 4.2 Filling Missing values with 0</b></font>

# %%
full_data[['MasVnrArea','BsmtHalfBath', 'BsmtFullBath','BsmtFinSF1','TotalBsmtSF','BsmtUnfSF','BsmtFinSF2','GarageCars','GarageArea']]= full_data[['MasVnrArea','BsmtHalfBath', 'BsmtFullBath','BsmtFinSF1','TotalBsmtSF','BsmtUnfSF','BsmtFinSF2','GarageCars','GarageArea']].fillna(0)

# %%
NA_columns = ['FireplaceQu','GarageCond', 'GarageQual', 'GarageFinish', 'GarageType', 'BsmtCond', 'BsmtExposure', 'BsmtQual', 'BsmtFinType2', 'BsmtFinType1', 'MasVnrType']
full_data[NA_columns]= full_data[NA_columns].fillna('None')

lowNA = ['MSZoning','Utilities','Exterior1st','Exterior2nd','KitchenQual','Functional','SaleType', 'Electrical']
for i in lowNA:
    full_data[i] = full_data[i].fillna(full_data[i].mode()[0])

# %%
print("All Na values are taken care")
display((full_data.isna().sum()[full_data.isna().sum()>0]).sort_values(ascending=False))
# Out:
# All Na values are taken care
# SalePrice    1459
# dtype: int64

# %% [markdown]
# <a id="4.3"></a>
# ### <font color ='green'><b>4.3 Check for skewness in features and transform them. </font></b>

# %% [markdown]
# + Below we are going to find the features which are skewed and convert them to normal distribution. We used the threshold as greater than 0.5.

# %%
categorical_features = full_data.select_dtypes(include=['object'])
numerical_features =full_data.select_dtypes(exclude=['object'])

# %%
skewed_features = []
for i in numerical_features:
    skewed_features.append([i, numerical_features[i].skew()])

# %%
skewed_features
# Out:
# [['MSSubClass', 1.3758383144615385],
#  ['LotArea', 13.116240381085582],
#  ['OverallQual', 0.18968844229864307],
#  ['OverallCond', 0.5696067720065279],
#  ['YearBuilt', -0.5995026808985219],
#  ['YearRemodAdd', -0.4503653717660427],
#  ['MasVnrArea', 2.6230683465481532],
#  ['BsmtFinSF1', 0.981149194818779],
#  ['BsmtFinSF2', 4.146635976494419],
#  ['BsmtUnfSF', 0.9201614522844864],
#  ['TotalBsmtSF', 0.6720970564192298],
#  ['1stFlrSF', 1.2579329323447708],
#  ['2ndFlrSF', 0.8619988496452764],
#  ['LowQualFinSF', 12.090757076763417],
#  ['GrLivArea', 1.06930033142033],
#  ['BsmtFullBath', 0.6227350310732301],
#  ['BsmtHalfBath', 3.9320182078879196],
#  ['FullBath', 0.16559942383702825],
#  ['HalfBath', 0.6970244365965833],
#  ['BedroomAbvGr', 0.32673631248194557],
#  ['KitchenAbvGr', 4.3027630269165],
#  ['TotRmsAbvGrd', 0.7496176182552688],
#  ['Fireplaces', 0.7256511193144619],
#  ['GarageCars', -0.21941006983560973],
#  ['GarageArea', 0.21696847677690778],
# ...

# %% [markdown]
# <b>Threshold skewness of 0.5

# %%
high_skewed = []
high_skewed_names=[]
for i in range(len(skewed_features)):
    if skewed_features[i][1] > 0.5:
        high_skewed.append(skewed_features[i])
        high_skewed_names.append(skewed_features[i][0])

# %% [markdown]
# <a id="4.4"></a>
#
# ### <font color ='green'><b>4.4 Transform skewed features </font></b>

# %%
for i in high_skewed_names:
    full_data[i] = boxcox1p(full_data[i], boxcox_normmax(full_data[i]+1))

# %% [markdown]
# <a id="4.5"></a>
#
# ### <font color ='green'><b>4.5 Convert categorical to continuous using get_dummies </font></b>

# %% [markdown]
# + We are using ```get_dummies``` method to convert the categorical to continous variables.

# %%
full_data = pd.get_dummies(full_data)
full_data = full_data.loc[:,~full_data.columns.duplicated()]
full_data.shape
# Out:
# (2917, 283)

# %% [markdown]
# <a id="4.6"></a>
# ### <font color ='green'><b>4.6 Create new train and test(submission) datasets</font></b>

# %% [markdown]
# + Now we have split the data back to new train and new test which is processed.

# %%
new_train = full_data.iloc[:1458, :]
new_test = full_data.iloc[1458:, :]
new_test.drop(columns='SalePrice', axis=1, inplace=True)

# %%
check_length(train)
# Out:
# Categorical variables length: 43
#
# Continuous variables length: 37
# (['MSZoning',
#   'Street',
#   'Alley',
#   'LotShape',
#   'LandContour',
#   'Utilities',
#   'LotConfig',
#   'LandSlope',
#   'Neighborhood',
#   'Condition1',
#   'Condition2',
#   'BldgType',
#   'HouseStyle',
#   'RoofStyle',
#   'RoofMatl',
#   'Exterior1st',
#   'Exterior2nd',
#   'MasVnrType',
#   'ExterQual',
#   'ExterCond',
#   'Foundation',
#   'BsmtQual',
#   'BsmtCond',
#   'BsmtExposure',
#   'BsmtFinType1',
#   'BsmtFinType2',
#   'Heating',
#   'HeatingQC',
#   'CentralAir',
#   'Electrical',
#   'KitchenQual',
#   'Functional',
#   'FireplaceQu',
#   'GarageType',
#   'GarageFinish',
#   'GarageQual',
#   'GarageCond',
#   'PavedDrive',
#   'PoolQC',
#   'Fence',
#   'MiscFeature',
#   'SaleType',
#   'SaleCondition'],
#  ['MSSubClass',
#   'LotFrontage',
#   'LotArea',
#   'OverallQual',
#   'OverallCond',
#   'YearBuilt',
#   'YearRemodAdd',
#   'MasVnrArea',
#   'BsmtFinSF1',
# ...

# %% [markdown]
# <a id="4.7"></a>
# ### <font color ='green'><b>4.7 Create new train and test(internal testing) datasets</font></b>

# %% [markdown]
# ### <font color ='green'><b> Used Train Test Split</font></b>

# %% [markdown]
# + ```targets``` will be the final target variable and ```df_final``` is out train set.

# %%
targets = new_train['SalePrice']
df_final = new_train.drop(columns='SalePrice', axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train_base, X_test_base, y_train_base, y_test_base = train_test_split(df_final, targets, test_size= 0.2, random_state=0)

# %% [markdown]
# + We are going to use these base data fields for our modelling in the coming sections. ```X_train_base, X_test_base, y_train_base, y_test_base```

# %% [markdown]
# <a id="4.8"></a>
#
# ### <font color ='green'><b>4.8 Plotting PCA with n_components = 0.9</font></b>

# %% [markdown]
# PCA is defined as an orthogonal linear transformation that transforms the data to a new coordinate system such that the greatest variance by some scalar projection of the data comes to lie on the first coordinate (called the first principal component), the second greatest variance on the second coordinate, and so on.[[wiki]](https://en.wikipedia.org/wiki/Principal_component_analysis)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_base)
X_test_scaled = scaler.transform(X_test_base)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 0.9)
df_pca = pca.fit_transform(X_train_scaled)

plt.figure(figsize =(8, 6))
plt.scatter(df_pca[:, 0], df_pca[:, 1], c = y_train_base, cmap ='Paired')
# labeling x and y axes
plt.xlabel('1st  Principal Component')
plt.ylabel('2nd Principal Component');

# %%
from sklearn.pipeline import make_pipeline
pca_scaled = make_pipeline(PCA(n_components = 0.85))
pca_scaled.fit(X_train_scaled)
pca = pca_scaled.named_steps['pca']

plt.figure(figsize=(20,10))
plt.semilogy(np.cumsum(pca.explained_variance_ratio_*100), 'b^')
plt.xlabel("Component index", fontsize = 14)
plt.ylabel("Explained variance (%)", fontsize = 14)

plt.xticks(np.arange(0, 300, 5))

# plt.yticks(np.arange(0, 11, 1))
# plt.xticks(x_array,rotation=45)
# plt.yticks(y_array,rotation=45)
plt.show()

# %% [markdown]
# <b>Observation: </b>
# + By using 80% as n components we are able to get around 85% of explained variance.
# + Lets test out different components in teh coming sections in the randomcvsearch.
#
# <a href="#top">Back to top of page</a>

# %% [markdown]
# <a id="5"></a>
#
# ## <font color ='brown'><b> 5. Explore many different models and shortlist the best ones : </b></font>

# %% [markdown]
# ---
# *(If the data is huge, you may want to sample smaller training sets so you can train many different models in a reasonable time.Try to automate these steps as much as possible. Train many quick-and-dirty models from different categories using standard parameters. Measure and compare their performance. For each model, use N-fold cross-validation and compute the mean and standard deviation of the performance measure on the N folds.
# Analyze the most significant variables for each algorithm. Analyze the types of errors the models make. Perform a quick round of feature selection and engineering. Perform one or two more quick iterations of the above steps. Shortlist the top three to five most promising models.)*

# %% [markdown]
# <a id="5.1"></a>
# #### <font color ='green'><b> 5.1 Creating a function to test the model accuracy and update the data in a table  </b></font>

# %%
from math import sqrt
metric_table = pd.DataFrame()
metric_table['Model']=""
metric_table['MAE']=""
metric_table['MSE']=""
metric_table['RMSE']=""
metric_table['R2']=""


def check_accuracy(model,X_train, X_test, y_train, y_test,metric_table):
#     scaler = MinMaxScaler()
#     X_train = scaler.fit_transform(X_train)
#     X_test = scaler.transform(X_test)
    
    model.fit(X_train,y_train)
    test_predictions = model.predict(X_test)
    tree_mse = round(mean_squared_error(y_test, test_predictions),4)
    tree_rmse = round(np.sqrt(tree_mse),4)
    tree_mae = round(mean_absolute_error(y_test, test_predictions),4)
    tree_r2 = round(r2_score(y_test, test_predictions),4)
    print("Model MAE is {}, r2 score is {} ".format( tree_mae, tree_r2))

    dictionary = {'Model': str(model),'MAE' : tree_mae, 'MSE': tree_mse, 'RMSE': tree_rmse, 'R2': tree_r2}

    metric_table = metric_table.append(dictionary, ignore_index=True)
    
    print("Plotting Prediction Errors for ",str(model))
    plot_model = PredictionError(model)
    plot_model.fit(X_train, y_train)
    plot_model.score(X_test, y_test)
    plot_model.show()
    
    return metric_table

# %% [markdown]
# <a id="5.2"></a>
# #### <font color ='green'><b> 5.2 Running different regression models with default hyper parameters to test the accuracy</b></font>

# %% [markdown]
# <a id="5.2.1"></a>
#
# <font color ='green'><b> 5.2.1 Linear Regression</b></font>

# %%
from sklearn.linear_model import LinearRegression
linear_model = LinearRegression()
metric_table=check_accuracy(linear_model,X_train_base, X_test_base, y_train_base, y_test_base,metric_table)
# Out:
# Model MAE is 0.0767, r2 score is 0.9348
# Plotting Prediction Errors for  LinearRegression()

# %% [markdown]
# <a id="5.2.2"></a>
# <font color ='green'><b> 5.2.2 Random Forest Regressor</b></font>

# %%
from sklearn.ensemble import RandomForestRegressor

random_regressor = RandomForestRegressor()
metric_table=check_accuracy(random_regressor,X_train_base, X_test_base, y_train_base, y_test_base,metric_table)
# Out:
# Model MAE is 0.0915, r2 score is 0.9117
# Plotting Prediction Errors for  RandomForestRegressor()

# %% [markdown]
# <a id="5.2.3"></a>
# <font color ='green'><b> 5.2.3 Decision Tree Regressor</b></font>

# %%
Dec_tree = DecisionTreeRegressor(random_state=42)
metric_table=check_accuracy(Dec_tree,X_train_base, X_test_base, y_train_base, y_test_base,metric_table)
# Out:
# Model MAE is 0.1298, r2 score is 0.8219
# Plotting Prediction Errors for  DecisionTreeRegressor(random_state=42)

# %% [markdown]
# <a id="5.2.41"></a>
# <font color ='green'><b> 5.2.4 LGBM Regressor</b></font>

# %%
from lightgbm import LGBMRegressor
LGBM_model = LGBMRegressor()
metric_table=check_accuracy(LGBM_model,X_train_base, X_test_base, y_train_base, y_test_base,metric_table)
# Out:
# Model MAE is 0.0864, r2 score is 0.9212
# Plotting Prediction Errors for  LGBMRegressor()

# %% [markdown]
# <a id="5.2.5"></a>
# <font color ='green'><b> 5.2.5 Ridge Regression</b></font>

# %%
from sklearn.linear_model import Ridge
ridge_model = Ridge()
metric_table=check_accuracy(ridge_model,X_train_base, X_test_base, y_train_base, y_test_base,metric_table)
# Out:
# Model MAE is 0.0749, r2 score is 0.9374
# Plotting Prediction Errors for  Ridge()

# %% [markdown]
# <a id="5.2.6"></a>
# <font color ='green'><b> 5.2.6 KNeighbors Regressor</b></font>

# %%
KNeighborsRegressor = KNeighborsRegressor()
metric_table=check_accuracy(KNeighborsRegressor,X_train_base, X_test_base, y_train_base, y_test_base,metric_table)
# Out:
# Model MAE is 0.1448, r2 score is 0.7619
# Plotting Prediction Errors for  KNeighborsRegressor()

# %% [markdown]
# <a id="5.2.7"></a>
# <font color ='green'><b> 5.2.7 Epsilon-Support Vector Regressor</b></font>

# %%
svr = SVR()
metric_table=check_accuracy(svr,X_train_base, X_test_base, y_train_base, y_test_base,metric_table)
# Out:
# Model MAE is 0.1348, r2 score is 0.7976
# Plotting Prediction Errors for  SVR()

# %% [markdown]
# <a id="5.2.8"></a>
# <font color ='green'><b> 5.2.8 ExtraTrees Regressor</b></font>

# %%
ETR = ExtraTreesRegressor()
metric_table=check_accuracy(ETR,X_train_base, X_test_base, y_train_base, y_test_base,metric_table)
# Out:
# Model MAE is 0.0983, r2 score is 0.8999
# Plotting Prediction Errors for  ExtraTreesRegressor()

# %% [markdown]
# <a id="5.2.9"></a>
# <font color ='green'><b> 5.2.9 Gradient Boosting Regressor</b></font>

# %%
GBR = GradientBoostingRegressor()
metric_table=check_accuracy(GBR,X_train_base, X_test_base, y_train_base, y_test_base,metric_table)
# Out:
# Model MAE is 0.0863, r2 score is 0.9221
# Plotting Prediction Errors for  GradientBoostingRegressor()

# %% [markdown]
# <a id="5.2.10"></a>
# <font color ='green'><b> 5.2.10 XGB Regressor</b></font>

# %%
from xgboost import XGBRegressor

xgb_model_withdefault = XGBRegressor()
# Add silent=True to avoid printing out updates with each cycle
xgb_model_withdefault.fit(X_train_base, y_train_base, verbose=False)
metric_table=check_accuracy(xgb_model_withdefault,X_train_base, X_test_base, y_train_base, y_test_base,metric_table)
# Out:
# Model MAE is 0.0886, r2 score is 0.9088
# Plotting Prediction Errors for  XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=0, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %% [markdown]
# <a href="#top">Back to top of page</a>

# %% [markdown]
# <a id="5.3"></a>
# #### <font color ='green'><b> 5.3 Running different regression models with ```cross_val_score``` to test the accuracy</b></font>

# %% [markdown]
# By running the models with ```cross_val_score``` we are able to check different training and testing sets.

# %%
models = [linear_model,random_regressor,Dec_tree,LGBM_model,ridge_model,KNeighborsRegressor,svr,ETR,GBR]

# %%
from sklearn.model_selection import cross_val_score

cross_metrics = pd.DataFrame()
cross_metrics['Model']=""
cross_metrics['R2']=""
cross_metrics['Mean_R2']=""

# Function for cross-validation

def cross_validation(model,x_train=df_final,y_train=targets,cv=10,scoring="r2",cross_metrics=cross_metrics):
    scores = cross_val_score(model,x_train, y_train,
                             scoring=scoring, cv=cv)

    r2_scores = np.sqrt(scores)
#     RMSLE= np.sqrt(mean_squared_log_error(y_test, test_predictions))
#     print(r2_scores)
#     print(r2_scores.max())
    dictionary = {'Model': str(model), 'R2': r2_scores, 'Mean_R2': r2_scores.mean()}

    cross_metrics = cross_metrics.append(dictionary, ignore_index=True)
    print("Mean for {} r2 score is {}".format(model, r2_scores.mean()))
    
    return cross_metrics

# %%
for i in models:
    cross_metrics=cross_validation(i,x_train=df_final,y_train=targets,cv=10,scoring="r2",cross_metrics=cross_metrics)
# Out:
# Mean for LinearRegression() r2 score is 0.9568795653250775
# Mean for RandomForestRegressor() r2 score is 0.9403718291208133
# Mean for DecisionTreeRegressor(random_state=42) r2 score is 0.8798397051127947
# Mean for LGBMRegressor() r2 score is 0.9515345474208479
# Mean for Ridge() r2 score is 0.9599179991464254
# Mean for KNeighborsRegressor() r2 score is 0.8643746504583104
# Mean for SVR() r2 score is 0.8719142641819844
# Mean for ExtraTreesRegressor() r2 score is 0.9417521754211229
# Mean for GradientBoostingRegressor() r2 score is 0.9533623012500099

# %%
cross_metrics
# Out:
#                                     Model                                                 R2   Mean_R2
# 0                      LinearRegression()  [0.947568830102189, 0.9649901393122542, 0.9663...  0.956880
# 1                 RandomForestRegressor()  [0.9200507629185835, 0.9495803003678637, 0.949...  0.940372
# 2  DecisionTreeRegressor(random_state=42)  [0.8522799703699387, 0.8380241517168594, 0.871...  0.879840
# 3                         LGBMRegressor()  [0.9362566846788045, 0.966404868976806, 0.9618...  0.951535
# 4                                 Ridge()  [0.9540082274235342, 0.968203804315778, 0.9691...  0.959918
# 5                   KNeighborsRegressor()  [0.841690574429472, 0.8973791042872735, 0.8815...  0.864375
# 6                                   SVR()  [0.8651094545808835, 0.9024192436731547, 0.886...  0.871914
# 7                   ExtraTreesRegressor()  [0.9400641360051013, 0.9570179942661713, 0.942...  0.941752
# ...

# %% [markdown]
# ### Rounding the score values

# %%
def round_list(unrounded_list):
    my_rounded_list = [ round(elem, 4) for elem in unrounded_list ]
    return my_rounded_list

cross_metrics['Mean_R2'] = [ round(elem, 4) for elem in cross_metrics['Mean_R2']]
cross_metrics['R2'] = cross_metrics['R2'].apply(lambda row: round_list(row))
cross_metrics
# Out:
#                                     Model                                                 R2  Mean_R2
# 0                      LinearRegression()  [0.9476, 0.965, 0.9663, 0.9506, 0.9488, 0.9559...   0.9569
# 1                 RandomForestRegressor()  [0.9201, 0.9496, 0.9494, 0.9429, 0.9322, 0.949...   0.9404
# 2  DecisionTreeRegressor(random_state=42)  [0.8523, 0.838, 0.8719, 0.8938, 0.9101, 0.9212...   0.8798
# 3                         LGBMRegressor()  [0.9363, 0.9664, 0.9618, 0.9462, 0.9419, 0.953...   0.9515
# 4                                 Ridge()  [0.954, 0.9682, 0.9691, 0.9525, 0.951, 0.9596,...   0.9599
# 5                   KNeighborsRegressor()  [0.8417, 0.8974, 0.8815, 0.8773, 0.8642, 0.872...   0.8644
# 6                                   SVR()  [0.8651, 0.9024, 0.887, 0.8936, 0.8769, 0.8706...   0.8719
# 7                   ExtraTreesRegressor()  [0.9401, 0.957, 0.9428, 0.9442, 0.9072, 0.9454...   0.9418
# ...

# %% [markdown]
# <a id="5.4"></a>
# #### <font color ='green'><b> 5.4 Testing on Neural Networks(Experimental)</b></font>

# %%
from sklearn.neural_network import MLPRegressor

mlp_relu = MLPRegressor(solver="lbfgs").fit(X_train_base, y_train_base)

mlp_tanh = MLPRegressor(solver="lbfgs", activation='tanh').fit(X_train_base, y_train_base)
metric_table=check_accuracy(mlp_relu,X_train_base, X_test_base, y_train_base, y_test_base,metric_table)
metric_table=check_accuracy(mlp_tanh,X_train_base, X_test_base, y_train_base, y_test_base,metric_table)
metric_table
# Out:
# Model MAE is 0.5233, r2 score is -2.0306
# Plotting Prediction Errors for  MLPRegressor(solver='lbfgs')
# Model MAE is 0.1997, r2 score is 0.6175
# Plotting Prediction Errors for  MLPRegressor(activation='tanh', solver='lbfgs')
#                                                 Model     MAE     MSE    RMSE      R2
# 0                                  LinearRegression()  0.0767  0.0110  0.1049  0.9348
# 1                             RandomForestRegressor()  0.0915  0.0150  0.1225  0.9117
# 2              DecisionTreeRegressor(random_state=42)  0.1298  0.0302  0.1738  0.8219
# 3                                     LGBMRegressor()  0.0864  0.0134  0.1158  0.9212
# 4                                             Ridge()  0.0749  0.0106  0.1030  0.9374
# 5                               KNeighborsRegressor()  0.1448  0.0404  0.2010  0.7619
# 6                                               SVR()  0.1348  0.0343  0.1852  0.7976
# ...

# %% [markdown]
# <a href="#top">Back to top of page</a>

# %% [markdown]
# <a id="5.5"></a>
# #### <font color ='green'><b> 5.5 Testing with Keras Regression - Using a Scalar</b></font>

# %%
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train_base)
X_test_scaled = scaler.transform(X_test_base)

# %%
import tensorflow as tf
from tensorflow import keras
# create model
model = keras.models.Sequential([
    keras.layers.Dense(300, activation="relu", input_shape=X_train_scaled.shape[1:]),
    keras.layers.Dense(1)
])

# compile
model.compile(loss="mean_squared_error", optimizer=keras.optimizers.SGD(lr=1e-3))

# train
history = model.fit(X_train_scaled, y_train_base, epochs=100, validation_data=(X_test_scaled, y_test_base))

# predict
mse_test = model.evaluate(X_test_scaled, y_test_base)
X_new = X_test_scaled[:3]
y_pred = model.predict(X_new)
# Out:
# Epoch 1/100
# 37/37 [==============================] - 0s 3ms/step - loss: 21.9246 - val_loss: 0.6516
# Epoch 2/100
# 37/37 [==============================] - 0s 1ms/step - loss: 0.5752 - val_loss: 0.5970
# Epoch 3/100
# 37/37 [==============================] - 0s 1ms/step - loss: 0.5114 - val_loss: 0.5250
# Epoch 4/100
# 37/37 [==============================] - 0s 2ms/step - loss: 0.4551 - val_loss: 0.4754
# Epoch 5/100
# 37/37 [==============================] - 0s 2ms/step - loss: 0.4107 - val_loss: 0.4323
# Epoch 6/100
# 37/37 [==============================] - 0s 1ms/step - loss: 0.3713 - val_loss: 0.3947
# Epoch 7/100
# 37/37 [==============================] - 0s 2ms/step - loss: 0.3374 - val_loss: 0.3703
# Epoch 8/100
# 37/37 [==============================] - 0s 1ms/step - loss: 0.3087 - val_loss: 0.3350
# Epoch 9/100
# 37/37 [==============================] - 0s 1ms/step - loss: 0.2837 - val_loss: 0.3112
# Epoch 10/100
# ...

# %%
X_new = X_test_scaled
y_pred = model.predict(X_new)
# print(y_pred)
df = pd.DataFrame(history.history)
df.plot()
plt.grid(True)
plt.xlabel('Training epoch #', fontsize = 15)
plt.ylabel('Metrics value', fontsize = 15)
plt.legend(fontsize = 12)
plt.show()

# %%
# Regression Example With Boston Dataset: Baseline
from pandas import read_csv
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold


# define base model
def baseline_model():
	# create model
	model = Sequential()
	model.add(Dense(150,  kernel_initializer='normal', activation='relu'))
	model.add(Dense(1, kernel_initializer='normal'))
	# Compile model
	model.compile(loss='mean_squared_error', optimizer='adam')
	return model
# evaluate model
estimator = KerasRegressor(build_fn=baseline_model, epochs=100, batch_size=20, verbose=0)
kfold = KFold(n_splits=10)
results = cross_val_score(estimator, X_train_scaled, y_train_base, cv=kfold)
print("Baseline: %.2f (%.2f) MSE" % (results.mean(), results.std()))
# Out:
# Baseline: -0.02 (0.00) MSE

# %% [markdown]
# <a href="#top">Back to top of page</a>

# %% [markdown]
# <a id="6"></a>
# ## <font color ='brown'><b> 6 Fine-Tune the System</b></font>

# %% [markdown]
# ---
# *(You will want to use as much data as possible for this step, especially as you move toward the end of fine-tuning. As always, automate what you can. Fine-tune the hyperparameters using cross-validation. Try Ensemble methods. Combining your best models will often produce better performance than running them individually.
# Once you are confident about your final model, measure its performance on the test set to estimate the generalization error.)*

# %% [markdown]
# ## <font color = 'red'> Grid Search Below...It takes long time...Run with caution

# %% [markdown]
# <a id="6.1"></a>
#
# #### <font color ='green'><b>6.1 Creating RandomizedSearchCV pipeline to tune parameters for different models

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import collections
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
pd.set_option('display.max_columns', 500) # Setting pandas to display a N number of columns
pd.set_option('display.max_rows', 10) # Setting pandas to display a N number rows
pd.set_option('display.width', 1000) # Setting pandas dataframe display width to N
import matplotlib.pyplot as plt # data visualization library



# Libraries used for Modeling
from scipy import stats
from category_encoders import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import SimpleImputer, IterativeImputer
from sklearn.model_selection import KFold, StratifiedKFold, RandomizedSearchCV, train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, GradientBoostingRegressor, StackingRegressor
from sklearn.svm import SVR
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from xgboost import XGBRegressor, plot_importance as plot_importance_xgb
from lightgbm import LGBMRegressor, plot_importance as plot_importance_lgbm


# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
def testRegressor(regressor, x_test, y_test):
    predictions = regressor.predict(x_test)
    
    results = []
    
    mae = mean_absolute_error(y_test, predictions)
    mse = mean_squared_error(y_test, predictions)
    rmse = mean_squared_error(y_test, predictions, squared=False)
    r2 = r2_score(y_test, predictions)
    
    results.append(mae)
    results.append(mse)
    results.append(rmse)
    results.append(r2)
    
    print("\n\n#---------------- Test set results (Best Regressor) ----------------#\n")
    print("Mean Absolute Error (MAE), Mean Squared Error (MSE), Root Mean Squared Error (RMSE), R² Score:")
    print(results)
    
    return results

# %%
# Building a Pipeline responsible for finding best model and it's parameters
def defineBestModelPipeline(df, target, categorical_features, numeric_features):
    
    # Splitting data into Train and Test
    x_train, x_test, y_train, y_test = train_test_split(df, target, test_size=0.3, random_state=1)
    y_train = y_train.to_numpy() # Transforming training targets into numpy arrays
    y_test = y_test.to_numpy() # Transforming test targets into numpy arrays
    
    
    # Pipeline's data transformations
    # 1st -> Numeric Transformers (we'll try several different ones)
    numeric_transformer_1 = Pipeline(steps=[('imp', IterativeImputer(max_iter=10, random_state=1)),
                                            ('scaler', MinMaxScaler())])
    
    numeric_transformer_2 = Pipeline(steps=[('imp', IterativeImputer(max_iter=30, random_state=7)),
                                            ('scaler', StandardScaler())])
    
    numeric_transformer_3 = Pipeline(steps=[('imp', SimpleImputer(strategy='mean')),
                                            ('scaler', RobustScaler())])
    
    numeric_transformer_4 = Pipeline(steps=[('imp', SimpleImputer(strategy='median')),
                                            ('scaler', MaxAbsScaler())])
    
    
    # 2nd -> Categorical Transformer
    categorical_transformer = Pipeline(steps=[('frequent', SimpleImputer(strategy='most_frequent')),
                                              ('onehot', OneHotEncoder(use_cat_names=True))])
    
    
    # 3rd -> Different Data Transformation Steps, each one with a different numerical transformation
    data_transformations_1 = ColumnTransformer(transformers=[('num', numeric_transformer_1, numeric_features),
                                                             ('cat', categorical_transformer, categorical_features)])
    
    data_transformations_2 = ColumnTransformer(transformers=[('num', numeric_transformer_2, numeric_features),
                                                             ('cat', categorical_transformer, categorical_features)])
    
    data_transformations_3 = ColumnTransformer(transformers=[('num', numeric_transformer_3, numeric_features),
                                                             ('cat', categorical_transformer, categorical_features)])
    
    data_transformations_4 = ColumnTransformer(transformers=[('num', numeric_transformer_4, numeric_features),
                                                             ('cat', categorical_transformer, categorical_features)])
    
    
    
    # Applying different data transformations in RandomSearchCV to find 
    # the best imputing strategy, the best feature engineering strategy
    # and the best model with it's parameters
    pipe = Pipeline(steps=[('data_transformations', data_transformations_1), # Initializing data transformation step by choosing any of the above
                           ('feature_eng', PCA()), # Initializing feature engineering step by choosing any desired method
                           ('reg', SVR())]) # Initializing modeling step of the pipeline with any model object
                           #memory='cache_folder') -> Used to optimize memory when needed
    
    
    
    # Now, defining the grid of parameters to search for. RandomSearchCV will randomly chose
    # options for each step inside the dictionaries, and return the best one for us as our final pipeline.
    params_grid = [
                    {'data_transformations': [data_transformations_1, data_transformations_2, data_transformations_3, data_transformations_4],
                     'feature_eng': [None, 
                                     PCA(n_components=round(x_train.shape[1]*0.9)),
                                     PCA(n_components=round(x_train.shape[1]*0.8)),
                                     PCA(n_components=round(x_train.shape[1]*0.7)),
                                     TSNE(n_components=round(x_train.shape[1]*0.8)),
                                     TSNE(n_components=round(x_train.shape[1]*0.7)), 
                                     TSNE(n_components=round(x_train.shape[1]*0.6))],
                     'reg': [KNeighborsRegressor()],
                     'reg__n_neighbors': stats.randint(1, 10),
                     'reg__metric': ['minkowski', 'euclidean']},

        

                    {'data_transformations': [data_transformations_1, data_transformations_2, data_transformations_3, data_transformations_4],
                     'feature_eng': [None, 
                                     PCA(n_components=round(x_train.shape[1]*0.9)),
                                     PCA(n_components=round(x_train.shape[1]*0.8)),
                                     PCA(n_components=round(x_train.shape[1]*0.7)),
                                     TSNE(n_components=round(x_train.shape[1]*0.8)),
                                     TSNE(n_components=round(x_train.shape[1]*0.7)), 
                                     TSNE(n_components=round(x_train.shape[1]*0.6))],
                     'reg': [LinearRegression()]},


        
                    {'data_transformations': [data_transformations_1, data_transformations_2, data_transformations_3, data_transformations_4],
                     'feature_eng': [None, 
                                     PCA(n_components=round(x_train.shape[1]*0.9)),
                                     PCA(n_components=round(x_train.shape[1]*0.8)),
                                     PCA(n_components=round(x_train.shape[1]*0.7)),
                                     TSNE(n_components=round(x_train.shape[1]*0.8)),
                                     TSNE(n_components=round(x_train.shape[1]*0.7)), 
                                     TSNE(n_components=round(x_train.shape[1]*0.6))],
                     'reg': [SVR()],
                     'reg__C': stats.uniform(0.01, 100),
                     'reg__gamma': stats.uniform(0.01, 100)},


        
                    {'data_transformations': [data_transformations_1, data_transformations_2, data_transformations_3, data_transformations_4],
                     'feature_eng': [None, 
                                     PCA(n_components=round(x_train.shape[1]*0.9)),
                                     PCA(n_components=round(x_train.shape[1]*0.8)),
                                     PCA(n_components=round(x_train.shape[1]*0.7)),
                                     TSNE(n_components=round(x_train.shape[1]*0.8)),
                                     TSNE(n_components=round(x_train.shape[1]*0.7)), 
                                     TSNE(n_components=round(x_train.shape[1]*0.6))],
                     'reg': [DecisionTreeRegressor()],
                     'reg__criterion': ['gini', 'entropy'],
                     'reg__max_features': [None, "auto", "log2"],
                     'reg__max_depth': [None, stats.randint(1, 15)]},


        
                    {'data_transformations': [data_transformations_1, data_transformations_2, data_transformations_3, data_transformations_4],
                     'feature_eng': [None, 
                                     PCA(n_components=round(x_train.shape[1]*0.9)),
                                     PCA(n_components=round(x_train.shape[1]*0.8)),
                                     PCA(n_components=round(x_train.shape[1]*0.7)),
                                     TSNE(n_components=round(x_train.shape[1]*0.8)),
                                     TSNE(n_components=round(x_train.shape[1]*0.7)), 
                                     TSNE(n_components=round(x_train.shape[1]*0.6))],
                     'reg': [RandomForestRegressor()],
                     'reg__n_estimators': stats.randint(10, 300),
                     'reg__max_features': [None, "auto", "log2"],
                     'reg__max_depth': [None, stats.randint(1, 9)]},
        
                    
        
                    {'data_transformations': [data_transformations_1, data_transformations_2, data_transformations_3, data_transformations_4],
                     'feature_eng': [None, 
                                     PCA(n_components=round(x_train.shape[1]*0.9)),
                                     PCA(n_components=round(x_train.shape[1]*0.8)),
                                     PCA(n_components=round(x_train.shape[1]*0.7)),
                                     TSNE(n_components=round(x_train.shape[1]*0.8)),
                                     TSNE(n_components=round(x_train.shape[1]*0.7)), 
                                     TSNE(n_components=round(x_train.shape[1]*0.6))],
                     'reg': [ExtraTreesRegressor()],
                     'reg__n_estimators': stats.randint(10, 300),
                     'reg__max_features': [None, "auto", "log2"],
                     'reg__max_depth': [None, stats.randint(1, 9)]},

                    
        
                    {'data_transformations': [data_transformations_1, data_transformations_2, data_transformations_3, data_transformations_4],
                     'feature_eng': [None, 
                                     PCA(n_components=round(x_train.shape[1]*0.9)),
                                     PCA(n_components=round(x_train.shape[1]*0.8)),
                                     PCA(n_components=round(x_train.shape[1]*0.7)),
                                     TSNE(n_components=round(x_train.shape[1]*0.8)),
                                     TSNE(n_components=round(x_train.shape[1]*0.7)), 
                                     TSNE(n_components=round(x_train.shape[1]*0.6))],
                     'reg': [GradientBoostingRegressor()],
                     'reg__n_estimators': stats.randint(10, 300),
                     'reg__learning_rate': stats.uniform(0.01, 1.5),
                     'reg__max_depth': [None, stats.randint(1, 12)]},

        
        
                    {'data_transformations': [data_transformations_1, data_transformations_2, data_transformations_3, data_transformations_4],
                     'feature_eng': [None, 
                                     PCA(n_components=round(x_train.shape[1]*0.9)),
                                     PCA(n_components=round(x_train.shape[1]*0.8)),
                                     PCA(n_components=round(x_train.shape[1]*0.7)),
                                     TSNE(n_components=round(x_train.shape[1]*0.8)),
                                     TSNE(n_components=round(x_train.shape[1]*0.7)), 
                                     TSNE(n_components=round(x_train.shape[1]*0.6))],
                     'reg': [LGBMRegressor()],
                     'reg__n_estimators': stats.randint(1, 150),
                     'reg__learning_rate': stats.uniform(0.01, 1.2),
                     'reg__max_depth': [None, stats.randint(1, 9)]},


        
                    {'data_transformations': [data_transformations_1, data_transformations_2, data_transformations_3, data_transformations_4],
                     'feature_eng': [None, 
                                     PCA(n_components=round(x_train.shape[1]*0.9)),
                                     PCA(n_components=round(x_train.shape[1]*0.8)),
                                     PCA(n_components=round(x_train.shape[1]*0.7)),
                                     TSNE(n_components=round(x_train.shape[1]*0.8)),
                                     TSNE(n_components=round(x_train.shape[1]*0.7)), 
                                     TSNE(n_components=round(x_train.shape[1]*0.6))],
                     'reg': [XGBRegressor()],
                     'reg__n_estimators': stats.randint(1, 175),
                     'reg__eta': stats.uniform(0.01, 1.2),
                     'reg__max_depth': stats.randint(1, 10),
                     'reg__gamma': [None, stats.uniform(0.01, 1.2)]},


        
                    {'data_transformations': [data_transformations_1, data_transformations_2, data_transformations_3, data_transformations_4],
                     'feature_eng': [None, 
                                     PCA(n_components=round(x_train.shape[1]*0.9)),
                                     PCA(n_components=round(x_train.shape[1]*0.8)),
                                     PCA(n_components=round(x_train.shape[1]*0.7)),
                                     TSNE(n_components=round(x_train.shape[1]*0.8)),
                                     TSNE(n_components=round(x_train.shape[1]*0.7)), 
                                     TSNE(n_components=round(x_train.shape[1]*0.6))],
                     'reg': [StackingRegressor(estimators=[('svr', SVR(C=10, gamma=10)),
                                                           ('rf', RandomForestRegressor(max_depth=7, max_features=None, n_estimators=20, n_jobs=-1)),
                                                           ('xgb', XGBRegressor(eta=0.8, gamma=0.5, max_depth=None, n_estimators=30))], 
                                                final_estimator=LinearRegression())]},
        
        
        
                    {'data_transformations': [data_transformations_1, data_transformations_2, data_transformations_3, data_transformations_4],
                     'feature_eng': [None, 
                                     PCA(n_components=round(x_train.shape[1]*0.9)),
                                     PCA(n_components=round(x_train.shape[1]*0.8)),
                                     PCA(n_components=round(x_train.shape[1]*0.7)),
                                     TSNE(n_components=round(x_train.shape[1]*0.8)),
                                     TSNE(n_components=round(x_train.shape[1]*0.7)), 
                                     TSNE(n_components=round(x_train.shape[1]*0.6))],
                     'reg': [StackingRegressor(estimators=[('lgbm', LGBMRegressor(n_estimators=50, learning_rate=0.6, max_depth=8)),
                                                           ('etc', ExtraTreesRegressor(max_depth=8, max_features=None, n_estimators=20)),
                                                           ('gbt', GradientBoostingRegressor(learning_rate=0.9, max_depth=None, n_estimators=20))], 
                                                final_estimator=LinearRegression())]}
                ]
    
    
    # Now, we fit a RandomSearchCV to search over the grid of parameters defined above
    metrics = ['neg_mean_absolute_error', 'neg_mean_squared_error', 'neg_root_mean_squared_error', 'r2']
    
    best_model_pipeline = RandomizedSearchCV(pipe, params_grid, n_iter=300, scoring=metrics, 
                                             refit='neg_root_mean_squared_error', 
                                             n_jobs=-1, cv=4, random_state=42)

    best_model_pipeline.fit(x_train, y_train)
    
    
    # At last, we check the final results
    print("\n\n#---------------- Best Data Pipeline found in RandomSearchCV  ----------------#\n\n", best_model_pipeline.best_estimator_[0])
    print("\n\n#---------------- Best Feature Engineering technique found in RandomSearchCV  ----------------#\n\n", best_model_pipeline.best_estimator_[1])
    print("\n\n#---------------- Best Regressor found in RandomSearchCV  ----------------#\n\n", best_model_pipeline.best_estimator_[2])
    print("\n\n#---------------- Best Estimator's average (negative) RMSE Score on CV (validation set) ----------------#\n\n", best_model_pipeline.best_score_)
    
    return x_train, x_test, y_train, y_test, best_model_pipeline

# %% [markdown]
# ---------------------

# %% [markdown]
# <a href="#top">Back to top of page</a>

# %% [markdown]
# -------------

# %% [markdown]
# <a id="6.2"></a>
# #### <font color ='green'><b> 6.2 Running RandomizedSearchCV function on version 1 dataset</b></font>

# %% [markdown]
# ```df_final and targets``` are preprocessed dataframes

# %%
targets.shape,df_final.shape
object_cols,continuous_cols = check_length(df_final)
# Out:
# Categorical variables length: 0
#
# Continuous variables length: 282

# %%
# Calling the function above, returing train/test data and best model's pipeline
X_train, X_test, y_train, y_test, best_model_pipeline = defineBestModelPipeline(df_final, targets, object_cols, continuous_cols)
# Out:
# #---------------- Best Data Pipeline found in RandomSearchCV  ----------------#
#
#  ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('imp', SimpleImputer()),
#                                                  ('scaler', RobustScaler())]),
#                                  ['MSSubClass', 'LotArea', 'OverallQual',
#                                   'OverallCond', 'YearBuilt', 'YearRemodAdd',
#                                   'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#                                   'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF',
#                                   '2ndFlrSF', 'LowQualFinSF', 'GrLivArea',
#                                   'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#                                   'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr',
#                                   'TotRmsAbvGrd', 'Fireplaces', 'GarageCars',
#                                   'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
# ...

# %%
# Checking best model's performance on test data
test_set_results = testRegressor(best_model_pipeline, X_test, y_test)
# Out:
# #---------------- Test set results (Best Regressor) ----------------#
#
# Mean Absolute Error (MAE), Mean Squared Error (MSE), Root Mean Squared Error (RMSE), R² Score:
# [0.08370673098516337, 0.015710206077249496, 0.12534036092675613, 0.8971864570305536]

# %%
df_results = pd.DataFrame(best_model_pipeline.cv_results_)
display(df_results)
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time                         param_data_transformations       param_feature_eng                                          param_reg param_reg__learning_rate                               param_reg__max_depth param_reg__n_estimators param_reg__max_features param_reg__metric param_reg__n_neighbors param_reg__criterion param_reg__C param_reg__gamma param_reg__eta                                             params  split0_test_neg_mean_absolute_error  split1_test_neg_mean_absolute_error  split2_test_neg_mean_absolute_error  split3_test_neg_mean_absolute_error  mean_test_neg_mean_absolute_error  std_test_neg_mean_absolute_error  rank_test_neg_mean_absolute_error  split0_test_neg_mean_squared_error  split1_test_neg_mean_squared_error  split2_test_neg_mean_squared_error  split3_test_neg_mean_squared_error  mean_test_neg_mean_squared_error  std_test_neg_mean_squared_error  rank_test_neg_mean_squared_error  \
# ...

# %%
# Now visualizing all results and metrics obtained only by the best regressor
display(df_results[df_results['rank_test_neg_root_mean_squared_error'] == 1])
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time                         param_data_transformations      param_feature_eng           param_reg param_reg__learning_rate param_reg__max_depth param_reg__n_estimators param_reg__max_features param_reg__metric param_reg__n_neighbors param_reg__criterion param_reg__C param_reg__gamma param_reg__eta                                             params  split0_test_neg_mean_absolute_error  split1_test_neg_mean_absolute_error  split2_test_neg_mean_absolute_error  split3_test_neg_mean_absolute_error  mean_test_neg_mean_absolute_error  std_test_neg_mean_absolute_error  rank_test_neg_mean_absolute_error  split0_test_neg_mean_squared_error  split1_test_neg_mean_squared_error  split2_test_neg_mean_squared_error  split3_test_neg_mean_squared_error  mean_test_neg_mean_squared_error  std_test_neg_mean_squared_error  rank_test_neg_mean_squared_error  split0_test_neg_root_mean_squared_error  split1_test_neg_root_mean_squared_error  \
# ...

# %% [markdown]
# ------

# %% [markdown]
# <a id="6.3"></a>
# #### <font color ='green'><b> 6.3 Running RandomizedSearchCV function on version 2 dataset</b></font>

# %%
df_v2 = pd.read_csv('train.csv')
# Transforming our target into log scale, to help improve generalization
df_v2['SalePrice'] = np.log(df_v2.SalePrice)

# Separating our target
target_v2 = df_v2['SalePrice']

# Let's drop the highly null columns and our target from the original dataframe.
df_v2.drop(['Id', 'Alley', 'PoolQC', 'Fence', 'MiscFeature', 'SalePrice'], axis=1, inplace=True)

# Taking sell month and year as categorical columns
df_v2['YrSold'] = df_v2['YrSold'].astype('object')
df_v2['MoSold'] = df_v2['MoSold'].astype('object')
object_cols_v2,continuous_cols_v2 = check_length(df_v2)
# Out:
# Categorical variables length: 41
#
# Continuous variables length: 34

# %%
# Calling the function above, returing train/test data and best model's pipeline
x_train_v2, x_test_v2, y_train_v2, y_test_v2, best_model_pipeline_v2 = defineBestModelPipeline(df_v2, target_v2, object_cols_v2, continuous_cols_v2)


# Checking best model's performance on test data
test_set_results_v2 = testRegressor(best_model_pipeline_v2, x_test_v2, y_test_v2)
# Out:
# #---------------- Best Data Pipeline found in RandomSearchCV  ----------------#
#
#  ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('imp',
#                                                   IterativeImputer(random_state=1)),
#                                                  ('scaler', MinMaxScaler())]),
#                                  ['MSSubClass', 'LotFrontage', 'LotArea',
#                                   'OverallQual', 'OverallCond', 'YearBuilt',
#                                   'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#                                   'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
#                                   '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#                                   'GrLivArea', 'BsmtFullBath', 'Bsm...
#                                   'LandContour', 'Utilities', 'LotConfig',
#                                   'LandSlope', 'Neighborhood', 'Condition1',
# ...

# %%
# Visualizing all results and metrics, from all models, obtained by the RandomSearchCV steps
df_results_v2 = pd.DataFrame(best_model_pipeline_v2.cv_results_)

display(df_results_v2)
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time                         param_data_transformations      param_feature_eng                                          param_reg param_reg__learning_rate                               param_reg__max_depth param_reg__n_estimators param_reg__max_features param_reg__metric param_reg__n_neighbors param_reg__criterion param_reg__C param_reg__gamma param_reg__eta                                             params  split0_test_neg_mean_absolute_error  split1_test_neg_mean_absolute_error  split2_test_neg_mean_absolute_error  split3_test_neg_mean_absolute_error  mean_test_neg_mean_absolute_error  std_test_neg_mean_absolute_error  rank_test_neg_mean_absolute_error  split0_test_neg_mean_squared_error  split1_test_neg_mean_squared_error  split2_test_neg_mean_squared_error  split3_test_neg_mean_squared_error  mean_test_neg_mean_squared_error  std_test_neg_mean_squared_error  rank_test_neg_mean_squared_error  \
# ...

# %% [markdown]
# In the above table we can see all the iterations in the randomcvsearch and their respective results. Out of these we were returned with the best models to be used.

# %% [markdown]
# <font color ='green'><b> Now visualizing all results and metrics obtained only by the best classifier</b></font>

# %%
display(df_results_v2[df_results_v2['rank_test_neg_root_mean_squared_error'] == 1])
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time                         param_data_transformations param_feature_eng                                          param_reg param_reg__learning_rate param_reg__max_depth param_reg__n_estimators param_reg__max_features param_reg__metric param_reg__n_neighbors param_reg__criterion param_reg__C param_reg__gamma param_reg__eta                                             params  split0_test_neg_mean_absolute_error  split1_test_neg_mean_absolute_error  split2_test_neg_mean_absolute_error  split3_test_neg_mean_absolute_error  mean_test_neg_mean_absolute_error  std_test_neg_mean_absolute_error  rank_test_neg_mean_absolute_error  split0_test_neg_mean_squared_error  split1_test_neg_mean_squared_error  split2_test_neg_mean_squared_error  split3_test_neg_mean_squared_error  mean_test_neg_mean_squared_error  std_test_neg_mean_squared_error  rank_test_neg_mean_squared_error  split0_test_neg_root_mean_squared_error  \
# ...

# %% [markdown]
# <font color ='green'><b> Plotting Feature Importances</b></font>
#
# + We wanted to understand the feature importances from the model, but if the best pipeline found in RandomSearchCV applies dimensionality reduction or creates new features using PolynomialFeatures, it will be much harder to explain importances.
#
# + In a scenario that no transformations are applied to the features inside the pipeline, if the model is tree-based (RandomForestClassifier, for example), or linear regression-based (Logistic Regression, for example), then explaining most important features becomes much easier.
#
# + We can get the feature names by using the ```best_estimator_ and get_feature_names``` as below.

# %%
best_model_pipeline_v2.best_estimator_['data_transformations'].get_feature_names
# Out:
# <bound method ColumnTransformer.get_feature_names of ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('imp',
#                                                   IterativeImputer(random_state=1)),
#                                                  ('scaler', MinMaxScaler())]),
#                                  ['MSSubClass', 'LotFrontage', 'LotArea',
#                                   'OverallQual', 'OverallCond', 'YearBuilt',
#                                   'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#                                   'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
#                                   '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#                                   'GrLivArea', 'BsmtFullBath', 'Bsm...
#                                   'LandContour', 'Utilities', 'LotConfig',
#                                   'LandSlope', 'Neighborhood', 'Condition1',
# ...

# %% [markdown]
# <font color ='green'>Here, we access the categorical feature names generated by OneHotEncoder, and then concatenate them with the numerical feature names, in the same order our pipeline is applying data transformations</font>

# %%
categorical_features_after_onehot = best_model_pipeline_v2.best_estimator_.named_steps['data_transformations']\
                                        .transformers_[1][1].named_steps['onehot'].get_feature_names()

feature_names_in_order = continuous_cols + categorical_features_after_onehot

print(feature_names_in_order)
# Out:
# ['MSSubClass', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'MSZoning_C (all)', 'MSZoning_FV', 'MSZoning_RH', 'MSZoning_RL', 'MSZoning_RM', 'Street_Grvl', 'Street_Pave', 'LotShape_IR1', 'LotShape_IR2', 'LotShape_IR3', 'LotShape_Reg', 'LandContour_Bnk', 'LandContour_HLS', 'LandContour_Low', 'LandContour_Lvl', 'Utilities_AllPub', 'Utilities_NoSeWa', 'LotConfig_Corner', 'LotConfig_CulDSac', 'LotConfig_FR2', 'LotConfig_FR3', 'LotConfig_Inside', 'LandSlope_Gtl', 'LandSlope_Mod', 'LandSlope_Sev', 'Neighborhood_Blmngtn', 'Neighborhood_Blueste', 'Neighborhood_BrDale', 'Neighborhood_BrkSid
# ...

# %% [markdown]
# #### <font color ='green'><b>Plotting feature importances for XGB Model </b></font>

# %% [markdown]
# <font color ='green'>After getting the regressor which is the best fit we can plot the feature importance as below. We will be getting the feature numbers in theplot. We can see f25 is the best feature as per the plot.</font>

# %%
feature_names_in_order[24]
# Out:
# 'GarageArea'

# %%
# Plotting feature importances for XGB Model
plot_importance_xgb(best_model_pipeline_v2.best_estimator_.named_steps['reg'], height=0.5, 
title='Feature Importances for XGB regressor', importance_type='gain', max_num_features=20)

# %%
# # # Plotting feature importances of the best model, if sklearn tree-based (top 5 features)
# #print("\n#---------------- Bar plot with feature importances ----------------#")
# #feat_importances = pd.Series(best_model_pipeline.best_estimator_.named_steps['reg'].feature_importances_, index=feature_names_in_order)
# #feat_importances.nlargest(5).plot(kind='barh')


# # # Plotting feature importances of the best model, if linear regression-based (top 5 features)
# print("\n#---------------- Bar plot with feature importances ----------------#")
# feat_importances = pd.Series(best_model_pipeline.best_estimator_.named_steps['reg'].coef_, index=feature_names_in_order)
# feat_importances.nlargest(5).plot(kind='barh')

# # # Plotting feature importances for LGBM Model
# plot_importance_lgbm(best_model_pipeline.best_estimator_.named_steps['reg'], 
#                      figsize=(10, 4), title='Feature importances for LGBM Classifier',
#                      importance_type='gain', max_num_features=10)

# %%
best_model_pipeline_v2.best_estimator_.named_steps['reg']
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, eta=0.256695770050765,
#              gamma=0, gpu_id=-1, importance_type='gain',
#              interaction_constraints='', learning_rate=0.256695777,
#              max_delta_step=0, max_depth=5, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=154, n_jobs=0,
#              num_parallel_tree=1, random_state=0, reg_alpha=0, reg_lambda=1,
#              scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
plot_importance_xgb
# Out:
# <function xgboost.plotting.plot_importance(booster, ax=None, height=0.2, xlim=None, ylim=None, title='Feature importance', xlabel='F score', ylabel='Features', importance_type='weight', max_num_features=None, grid=True, show_values=True, **kwargs)>

# %% [markdown]
# <a href="#top">Back to top of page</a>

# %% [markdown]
# ---

# %% [markdown]
# <a id="7"></a>
# ## <font color ='brown'><b> 7. Present your solution : </b></font>

# %% [markdown]
# <!-- ### 6. Reporting Results -->
# ---
# *(Use appropriate methods to present the results including tables, plots, and bullet points. Explain how the analysis process and models solve the problem. Make sure you highlight the big picture first.
# Explain why your solution achieves the objective. Don’t forget to present interesting points you noticed along the way. Describe what worked and what did not. List your assumptions and your system’s limitations.)*

# %% [markdown]
# <b>R^2</b> (coefficient of determination) regression score function. We are using r2 score as our primary scaoring metric.
#
# Best possible score is 1.0 and it can be negative (because the model can be arbitrarily worse). A constant model that always predicts the expected value of y, disregarding the input features, would get a R^2 score of 0.0.

# %% [markdown]
# + We have first tested different models with default parameters. We have used Randomsearchcv to find the best hyper-parameters.
#
# + After testing all the hyper parameters we found below as the best solution to the problem.
# + Principal component analysis is used to reduce the dimensions from 282 features to 197 features.
# + We have the Linear Regression model  peforming well with the combination of PCA(n_components=197) and the scalar used is MinMaxScaler.

# %% [markdown]
# <a id="7.1"></a>
# #### <font color ='green'><b> 7.1 Base Model Scores </b></font>

# %%
print("Below we have the metrics for the base models without tuning the hyper-parameters")
metric_table
# Out:
# Below we have the metrics for the base models without tuning the hyper-parameters
#                                                 Model     MAE     MSE    RMSE      R2
# 0                                  LinearRegression()  0.0767  0.0110  0.1049  0.9348
# 1                             RandomForestRegressor()  0.0915  0.0150  0.1225  0.9117
# 2              DecisionTreeRegressor(random_state=42)  0.1298  0.0302  0.1738  0.8219
# 3                                     LGBMRegressor()  0.0864  0.0134  0.1158  0.9212
# 4                                             Ridge()  0.0749  0.0106  0.1030  0.9374
# 5                               KNeighborsRegressor()  0.1448  0.0404  0.2010  0.7619
# 6                                               SVR()  0.1348  0.0343  0.1852  0.7976
# 7                               ExtraTreesRegressor()  0.0983  0.0170  0.1304  0.8999
# 8                         GradientBoostingRegressor()  0.0863  0.0132  0.1149  0.9221
# ...

# %%
plt.figure(figsize=(10,6))
# make barplot and sort bars in descending order
labels = ['LinearRegression', 'RandomForestRegressor', 'DecisionTreeRegressor', 'LGBMRegressor','Ridge','KNeighborsRegressor','SVR','ExtraTreesRegressor','GradientBoostingRegressor','XGBRegressor','MLPRegressor','MLPRegressor_2']
sns.barplot(x=labels, y="R2", data=metric_table)
            
# set labels
plt.xticks(rotation=90)
plt.xlabel("Models", size=15)
plt.ylabel("R2 Value", size=15)
plt.title("Default Model Scores", size=18)
plt.tight_layout()

# %% [markdown]
# <a id="7.2"></a>
# #### <font color ='green'><b> 7.2 Base Model Scores with cross validation</b></font>

# %%
print("Below we have the metrics for the base models without tuning the hyper-parameters with the cros validation")
cross_metrics
# Out:
# Below we have the metrics for the base models without tuning the hyper-parameters with the cros validation
#                                     Model                                                 R2  Mean_R2
# 0                      LinearRegression()  [0.9476, 0.965, 0.9663, 0.9506, 0.9488, 0.9559...   0.9569
# 1                 RandomForestRegressor()  [0.9201, 0.9496, 0.9494, 0.9429, 0.9322, 0.949...   0.9404
# 2  DecisionTreeRegressor(random_state=42)  [0.8523, 0.838, 0.8719, 0.8938, 0.9101, 0.9212...   0.8798
# 3                         LGBMRegressor()  [0.9363, 0.9664, 0.9618, 0.9462, 0.9419, 0.953...   0.9515
# 4                                 Ridge()  [0.954, 0.9682, 0.9691, 0.9525, 0.951, 0.9596,...   0.9599
# 5                   KNeighborsRegressor()  [0.8417, 0.8974, 0.8815, 0.8773, 0.8642, 0.872...   0.8644
# 6                                   SVR()  [0.8651, 0.9024, 0.887, 0.8936, 0.8769, 0.8706...   0.8719
# ...

# %% [markdown]
# <a id="7.3"></a>
# #### <font color ='green'><b> 7.3 Grid Search Results - Dataset v1</b></font>

# %%
df_results
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time                         param_data_transformations       param_feature_eng                                          param_reg param_reg__learning_rate                               param_reg__max_depth param_reg__n_estimators param_reg__max_features param_reg__metric param_reg__n_neighbors param_reg__criterion param_reg__C param_reg__gamma param_reg__eta                                             params  split0_test_neg_mean_absolute_error  split1_test_neg_mean_absolute_error  split2_test_neg_mean_absolute_error  split3_test_neg_mean_absolute_error  mean_test_neg_mean_absolute_error  std_test_neg_mean_absolute_error  rank_test_neg_mean_absolute_error  split0_test_neg_mean_squared_error  split1_test_neg_mean_squared_error  split2_test_neg_mean_squared_error  split3_test_neg_mean_squared_error  mean_test_neg_mean_squared_error  std_test_neg_mean_squared_error  rank_test_neg_mean_squared_error  \
# ...

# %%
# best_model_pipeline.cv_results_
df_results['split0_test_r2'].max()
# Out:
# 0.9102118557500345

# %% [markdown]
# In the above table we can see all the iterations in the randomcvsearch and their respective results. Out of these we were returned with the best models to be used.

# %% [markdown]
# #### <font color ='green'><b> 7.3.2 Grid Search Results - Dataset v2</b></font>

# %%
df_results_v2
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time                         param_data_transformations      param_feature_eng                                          param_reg param_reg__learning_rate                               param_reg__max_depth param_reg__n_estimators param_reg__max_features param_reg__metric param_reg__n_neighbors param_reg__criterion param_reg__C param_reg__gamma param_reg__eta                                             params  split0_test_neg_mean_absolute_error  split1_test_neg_mean_absolute_error  split2_test_neg_mean_absolute_error  split3_test_neg_mean_absolute_error  mean_test_neg_mean_absolute_error  std_test_neg_mean_absolute_error  rank_test_neg_mean_absolute_error  split0_test_neg_mean_squared_error  split1_test_neg_mean_squared_error  split2_test_neg_mean_squared_error  split3_test_neg_mean_squared_error  mean_test_neg_mean_squared_error  std_test_neg_mean_squared_error  rank_test_neg_mean_squared_error  \
# ...

# %% [markdown]
# <a id="7.4"></a>
# #### <font color ='green'><b> 7.4 Plotting train and test data using Yellowbrick visualiser </b></font>

# %%
visualizer = ResidualsPlot(best_model_pipeline, hist=False)
print("Dataset v1")

visualizer.fit(X_train, y_train) # Fit the training data to the visualizer
visualizer.score(X_test, y_test) # Evaluate the model on the test data
visualizer.show()
# Out:
# Dataset v1

# %%
visualizer = ResidualsPlot(best_model_pipeline_v2, hist=False)
print("Dataset v2")

visualizer.fit(x_train_v2, y_train_v2) # Fit the training data to the visualizer
visualizer.score(x_test_v2, y_test_v2) # Evaluate the model on the test data
visualizer.show()
# Out:
# Dataset v2

# %% [markdown]
# In the above plots we can see the residuals of the final models. Residuals is the difference between the observed value of the target variable (y) and the predicted value (ŷ), i.e. the error of the prediction. The residuals plot shows the difference between residuals on the vertical axis and the dependent variable on the horizontal axis, allowing us to detect regions within the target that may be susceptible to more or less error.

# %%
from yellowbrick.regressor import prediction_error
print("Dataset v1")
visualizer1 = prediction_error(best_model_pipeline, X_train, y_train, X_test, y_test)
print("Dataset v2")
visualizer2 = prediction_error(best_model_pipeline_v2, x_train_v2, y_train_v2, x_test_v2, y_test_v2)
print("Dataset v3 - Base model used - Ridge Regressor")
visualizer2 = prediction_error(ridge_model, X_train_base, y_train_base, X_test_base, y_test_base)
# Out:
# Dataset v1
# Dataset v2
# Dataset v3 - Base model used - Ridge Regressor

# %% [markdown]
# In the above figure we can see the prediction error plot with actual targets from the dataset against the predicted values generated by our model. This lets us see how much variance is in the model. The 45 degree line is where the prediction exactly matches the model.

# %% [markdown]
# <a id="7.5"></a>
# #### <font color ='green'><b>7.5 Predictions</b></font>
#
# + Now that we have tried different preprocessing and modeling techniques, resulting in a final best pipeline, let's use it to predict the test data provided by kaggle.
#
# + Now lets import the test data from kaggle competetion

# %%
# df_test = pd.read_csv("../input/house-prices-advanced-regression-techniques/test.csv")
df_test = pd.read_csv('test.csv')

# %% [markdown]
# + Applying best_model_pipeline:
# + Step 1 -> Transforming data the same way we did in the training set;
# + Step 2 -> making predictions using the best model obtained by RandomSearchCV.

# %%
# Dropping unnecessary columns
df_test.drop(['Id', 'Alley','PoolQC','Fence','MiscFeature'], axis=1, inplace=True)
test_predictions = best_model_pipeline_v2.predict(df_test)

# %% [markdown]
# + Because our model was trained using a logarithmic scale of the target, it's predictions will also be log. We need to get them back to linear scale using np.exp()

# %%
test_predictions = np.exp(test_predictions)
print(test_predictions)
# Out:
# [121971.78 159071.78 179397.39 ... 161133.31 121426.06 242664.48]

# %% [markdown]
# + Generating predictions file that is going to be submitted to the competition

# %%
df_submission = pd.read_csv("test.csv")

df_submission['SalePrice'] = test_predictions # Adding a column with predicted values

df_submission.drop(df_submission.columns.difference(['Id', 'SalePrice']), axis=1, inplace=True) # Selecting only needed columns

df_submission.head(10)
# Out:
#      Id      SalePrice
# 0  1461  121971.781250
# 1  1462  159071.781250
# 2  1463  179397.390625
# 3  1464  190533.484375
# 4  1465  191028.000000
# 5  1466  176586.625000
# 6  1467  174405.031250
# 7  1468  174392.890625
# 8  1469  167788.640625
# 9  1470  127169.101562

# %% [markdown]
# + Checking if the number of rows is OK (the file is expected to have 1459 rows) </b></font>

# %%
df_submission.count()
# Out:
# Id           1459
# SalePrice    1459
# dtype: int64

# %%
# Writing submitions to CSV file
df_submission.to_csv('submission.csv', index=False)

# %% [markdown]
# <a href="#top">Back to top of page</a>

# %% [markdown]
# <a id="8"></a>
# ## <font color ='brown'><b>8. Conclusion</b></font>
# ---
# *(Briefly describe what you have done and what you have achieved. Discuss any shortcomings of the process and results. **Finally, discuss the lessons learned from doing the project**.)*

# %% [markdown]
# <strong>Process followed:</strong>
#
# + From the regression analysis we tried to check the scores for different models and tuning different parameters.
# + We have tested 10 different regression models below.
#     * [5.2.1 Linear Regression](#5.2.1)
#     * [5.2.2 Random Forest Regressor](#5.2.2)
#     * [5.2.3 Decision Tree Regressor](#5.2.3)
#     * [5.2.4 LGBM Regressor](#5.2.4)
#     * [5.2.5 Ridge Regression](#5.2.5)
#     * [5.2.6 KNeighbors Regressor](#5.2.6)
#     * [5.2.7 Epsilon-Support Vector Regressor](#5.2.7)
#     * [5.2.8 ExtraTrees Regressor](#5.2.8)
#     * [5.2.9 Gradient Boosting Regressor](#5.2.9)
#     * [5.2.10 XGB Regressor](#5.2.10)
# + We are getting good r2 scores for the ```Ridge() and LinearRegression()``` with 96 and 95 % r2 scores. This test was done without scaling the data and still we got good scores.
# + We also experimented with neural networks but they were not used in the final models. We were mainly concentrating on boosting regressors and tuning the parameters on the base models.
# + We have created a function which uses different scaling techniques, PCA for dimensionality reduction and testing different hyper-parameters.
# + We have created two different datasets which could be tested on the hyper-parameter tuning.
# + Dataset v1 is preprocessed by imputing NA values, removing skewed features, and creating dummy variables for the categorical-continuous conversion.
# + Dataset v2 is processed by imputing missing values and uses all the functionality inside the ```randomcvsearch``` function and uses ```onehot-encoding``` inthe pipeline to encode  the features.
# + We have used two different kinds of pre-processing techniques and tested the ```randomcvsearch``` function on both the datasets.
# + For the first dataset the categorical encoding was done using ```dummy_variable``` and for the second we used onehotencoding.
# + Also the way NA values are imputed is different for both datasets.
# + We wanted to test the difference in the type of pre processing and check the models performance.
# + Scores were good for the Linear regressor on first dataset and XGB regressor on the second dataset.
# + With this we are clearly able to see the difference, which means that the preprocessing techniques are also playing important role other than the tuning of parameters for the performance of the models.
# + Finally XGboost was the best models among all.

# %% [markdown]
# <strong>Goal</strong> From this project we have tried to use all the techniques learned in this course.</br>
# <strong>Focus</strong> Our main focus was to understand the complete data science life cycle with main focus being the below steps.

# %% [markdown]
# 1. <strong>Get the Data:</strong> We have found a good dataset with which we can test most of the techniques we learned in this course.
# 2. <strong>Explore the Data:</strong> We have explored every variable and tried to get the relationships with the target variable. We found some of the issues like missing values, skewed variables and some of the features which do not have any importance.
# 3. <strong>Prepare the Data:</strong> The problems we found earlier in the exploration are corrected in this step. We have individually imputed missing values for different variables. We have dropped some features which are less important and not useful in the predictions.
# 4. <strong>Shortlist Promising Models:</strong> Once we got the data pre-procesed we trained different models with default parameters and tested their performance metrics both on the test data and also using cross validation on different sets of train and test data.
# 5. <strong>Fine-Tune the System:</strong> Once the data models are trained using default parameters, we created a function which uses different scaling methods, and different hyper parameters to tune the models. We also tried the same approach with different way of pre-processing the data to check how the models are performing.
# 6. <strong>Present Your Solution:</strong> Finally we were able to understand the best regressor using the randomcvsearch with different hyper parameters. We used this model to predict the target on the test data provided in the competetion.
# 7. <strong>Limitations:</strong>
#     * Running the grid/RandomCVsearch took a long time.
#     * We have run the keras and neural net models but have very limited knowledge and couldn't interpre the results to tune further. We would like to explore those models in the future deeply.
# 8. <strong>Future scope: </strong>
#     * This can be expanded with datasets from different locations.
#     * We have only used keras models as experimental, but they can be tuned further to improve the accuracy.
#     * We can create an application which can be used to get the estimated price of a house.

# %% [markdown]
# ---

# %% [markdown]
#  <font color = 'green'><b>Learning from this project:</b><font></br>
#
# #### From this project below are some things we learned.
#
# + We have learned the complete life cycle of data science.
# + We have learned how to tune the parameters of the machine learning models.
# + We have understood the mathematical concepts behind the machine learning models and how they effect the predictions with varied parameters.
# + We also experimented to see how different type of scaling methods show different effects on the training of the models.
# + Another experiment we have done in this project is to pre-process  the data differently and test the same models and see how they vary and we were able to cleary see the difference. We can see the same from 6.1 and 6.2 above.
#
# + you can see the results here <a href="#7">Click here to view the results</a>
#
#
#
# <a href="#top">Back to top of page</a>

# %% [markdown]
# --------------------

# %% [markdown]
# <a id="9"></a>
# ## <font color ='brown'><b>9. References</b></font>

# %% [markdown]
# www.Kaggle.com</br>
# https://www.kaggle.com/c/house-prices-advanced-regression-techniques/leaderboard</br>
# https://en.wikipedia.org/wiki/Principal_component_analysis</br>
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.r2_score.html</br>

# %% [markdown]
# ---
# (*Use the following requirements for writing your reports. DO NOT DELETE THE CELLS BELLOW*)

# %% [markdown]
# <a href="#top">Back to top of page</a>

# %% [markdown]
# # Project Requirements
#
# This final project examines the level of knowledge the students have learned from the course. The following course outcomes will be checked against the content of the report:
#
# Upon successful completion of this course, a student will be able to:
# * describe the mathematical concepts of machine learning algorithms (**However, you don't need to write the mathematical equations for each method you use. I will assume that you already know the math concepts behind the model when you use it in this project.**)
# * select and apply appropriate machine learning algorithms for data science problems
# * interpret the results of machine learning
# * perform parameter tuning and error analysis; and
# * compare the performance of multiple machine learning algorithms
#
#
# **Marking will be foucsed on both presentation and content.**
#
# ## Written Presentation Requirements
# The report will be judged on the basis of visual appearance, grammatical correctness, and quality of writing, as well as its contents. Please make sure that the text of your report is well-structured, using paragraphs, full sentences, and other features of well-written presentation.

# %% [markdown]
# <font color = 'red'>================================================= END OF PROJECT =================================================
#
# <a href="#top">Back to top of page</a>
